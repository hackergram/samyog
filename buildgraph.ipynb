# %%
import xetrapal, pandas,json
from arango import ArangoClient

from xetrapal import gdastras
a=xetrapal.karma.load_xpal_smriti("/opt/av-appdata/avxpal.json")
avxpal=xetrapal.Xetrapal(a)
config=xetrapal.karma.load_config_json(a.configfile)
pygsheetsconfig = xetrapal.karma.load_config_json(config['Pygsheets']['avdrive'])
gd = gdastras.gd_get_googledriver(pygsheetsconfig)
# Out:
# 2021-03-14 00:32:00 Xpal-Sutradhar-MainThread-[load_xpal_smriti] INFO : Loaded config from /opt/av-appdata/avxpal.json
# 2021-03-14 00:32:00 Sabka Baap-MainThread-[__init__] INFO : My name is Sabka Baap
# 2021-03-14 00:32:00 Sabka Baap-MainThread-[setup_disk] INFO : I already have a datapath at the location /opt/av-appdata/xetrapal-data
# 2021-03-14 00:32:00 Sabka Baap-MainThread-[start_session] INFO : Creating a new path for this session at /opt/av-appdata/xetrapal-data/SabkaBaap-2021Mar14-003200
# 2021-03-14 00:32:00 Sabka Baap-MainThread-[start_session] INFO : Creating a new download path for this session at /opt/av-appdata/xetrapal-data/SabkaBaap-2021Mar14-003200/downloads
# 2021-03-14 00:32:00 Sabka Baap-MainThread-[start_session] INFO : Creating a new json path for this session at /opt/av-appdata/xetrapal-data/SabkaBaap-2021Mar14-003200/json
# 2021-03-14 00:32:00 Sabka Baap-MainThread-[log_to_disk] INFO : Saving messages to log at /opt/av-appdata/xetrapal-data/SabkaBaap-2021Mar14-003200/jeevasession.log
# 2021-03-14 00:32:00 Sabka Baap-MainThread-[dhaarana] INFO : Trying to load module xetrapal.astra
# 2021-03-14 00:32:00 Sabka Baap-MainThread-[dhaarana] INFO : I now have functions ['get_browser', 'get_headless_browser', 'get_xpal_logger']
# 2021-03-14 00:32:00 Sabka Baap-MainThread-[dhaarana] INFO : Trying to load module xetrapal.karma
# 2021-03-14 00:32:00 Sabka Baap-MainThread-[dhaarana] INFO : I now have functions ['close_modal', 'copy_smriti', 'deepcopy', 'download_file', 'export_table', 'get_aadesh', 'get_browser', 'get_color_json', 'get_formatted_json', 'get_headless_browser', 'get_remote_smriti_status', 'get_smriti_status', 'get_xpal_logger', 'load_config', 'load_config_json', 'load_xpal_smriti', 'pull_smritis', 'save_config', 'save_data_to_jsonfile', 'scroll_page', 'scroll_to_bottom', 'scroll_up', 'urlopen', 'uuid4', 'wait']
# 2021-03-14 00:32:00 Sabka Baap-MainThread-[update_astras] INFO : Trying to update astras
# 2021-03-14 00:32:00 Sabka Baap-MainThread-[update_astras] WARNING : I dont seem to have any astras
# 2021-03-14 00:32:00 Sabka Baap-MainThread-[update_vaahans] INFO : Trying to update vaahans
# 2021-03-14 00:32:00 Sabka Baap-MainThread-[update_vaahans] WARNING : I dont seem to have any vaahans
# 2021-03-14 00:32:00 Xpal-Sutradhar-MainThread-[gd_get_googledriver] INFO : Trying to log into Google drive

# %%
with open("/home/arjun/api.json", "rb") as f:
    confjson = json.loads(f.read())


client = ArangoClient()
db = client.db(confjson['dbname'], username=confjson['username'], password=confjson['password'])
graph = db.graph(confjson['graphname'])
